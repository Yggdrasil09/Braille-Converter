# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
from torch.utils.data import DataLoader,Dataset
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
use_cuda = torch.cuda.is_available()

device = torch.device("cuda:0" if use_cuda else "cpu")

# %%
print(torch.version.cuda)
# Out:
# 10.0.130

# %%
#Preparing the dataset

data_path = 'data/dataset/'

train_dataset = torchvision.datasets.ImageFolder( root = data_path, transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((28,28)),
    transforms.ToTensor(),
])) 

len(train_dataset)
# Out:
# 26724

# %%
train_loader = DataLoader( train_dataset, batch_size = 64, num_workers = 0, shuffle = True)

# %%
sample = next(iter(train_dataset))

len(sample)
# Out:
# 2

# %%
image , label = sample

# %%
image.shape
# Out:
# torch.Size([1, 28, 28])

# %%
label
# Out:
# 0

# %%
plt.imshow(image.squeeze(),cmap="gray")
print('label: ',label)
# Out:
# label:  0

# %%
batch = next(iter(train_loader))

# %%
images , labels = batch

# %%
grid = torchvision.utils.make_grid(images,nrow=8)

plt.figure(figsize = (20,20))
plt.imshow(np.transpose(grid,(1,2,0)))

print('labels : ',labels)
# Out:
# labels :  tensor([17, 33, 10,  7, 18, 17, 10, 22,  5,  8,  0,  3,  7, 28, 18, 34,  7, 21,
#         20, 15,  8, 27, 13, 26, 24, 32, 12, 14, 28,  7, 28, 13, 14,  2,  6,  8,
#          9, 16, 30,  7,  7, 34, 36, 16, 10,  1, 31, 30, 24, 11, 11, 32,  4, 22,
#          6, 36, 25, 12, 36,  3, 19, 32, 34, 21])
